# %% [markdown]
# # Dependencies & load dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# sales price descritive summary
data["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# find the correlation coefficient
correlation = data.corr()
correlation
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
# correlation chart for all variables
f,ax = plt.subplots(figsize=(30,30)) 
# 
sns.heatmap(correlation, vmax = 1, square=True,annot=True,cmap="YlGnBu")

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'FullBath', 'YearBuilt','BldgType','BedroomAbvGr','HouseStyle']
sns.pairplot(data[cols], size = 2.5)
plt.show();

# %%
corr = data[cols].corr() # correlation of chosen columns
f,ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(corr, vmax = 1, square=True,annot=True,cmap="YlGnBu")

# %%
# histogram of the sales price
sns.distplot(data["SalePrice"])

# %%
# find out which room is more popular. 
data['BedroomAbvGr'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
# find relationship between price and GrLivArea
plt.scatter(data["GrLivArea"],data["SalePrice"],marker = "o")
plt.xlabel("GrLivArea")
plt.ylabel("Price")
plt.title("GrLivArea vs. Price")
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
# overall quality of the house has the highest correlation with Price
d = pd.concat([data['SalePrice'], data["OverallQual"]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x="OverallQual", y="SalePrice", data=d)
fig.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 9.5, 0, 800000)

# %%
# relationship with year built
var = 'YearBuilt'
da = pd.concat([data['SalePrice'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(40, 15))
fig = sns.boxplot(x=var, y="SalePrice", data=da)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);

# %% [markdown]
# # Dummy the categorical columns

# %%
# dummy the bldgType
dummy_v = pd.get_dummies(data)
dummy_v.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1          ...            \
# 0          2003       196.0         706          ...
# 1          1976         0.0         978          ...
# 2          2002       162.0         486          ...
# 3          1970         0.0         216          ...
# 4          2000       350.0         655          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
dummy_v.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=290)

# %%
# intersted cols:
columns = ["SalePrice","OverallQual","GrLivArea",
           "GarageCars","FullBath","YearBuilt",
           "BedroomAbvGr","BldgType_1Fam",'BldgType_2fmCon', 'BldgType_Duplex', 'BldgType_Twnhs',
       'BldgType_TwnhsE', 'CentralAir_N', 'CentralAir_Y', 'HouseStyle_1.5Fin',
       'HouseStyle_1.5Unf', 'HouseStyle_1Story', 'HouseStyle_2.5Fin',
       'HouseStyle_2.5Unf', 'HouseStyle_2Story', 'HouseStyle_SFoyer',
       'HouseStyle_SLvl']
df = dummy_v[columns]
df.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars  FullBath  YearBuilt  \
# 0     208500            7       1710           2         2       2003
# 1     181500            6       1262           2         2       1976
# 2     223500            7       1786           2         2       2001
# 3     140000            7       1717           3         1       1915
# 4     250000            8       2198           3         2       2000
#
#    BedroomAbvGr  BldgType_1Fam  BldgType_2fmCon  BldgType_Duplex  \
# 0             3              1                0                0
# 1             3              1                0                0
# 2             3              1                0                0
# 3             3              1                0                0
# 4             4              1                0                0
#
#         ...         CentralAir_N  CentralAir_Y  HouseStyle_1.5Fin  \
# 0       ...                    0             1                  0
# ...

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
X = df.drop(["SalePrice"],axis = 1)
y = df["SalePrice"].reshape(-1,1)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   from ipykernel import kernelapp as app

# %%
# fit model and R2 score
x_train,x_test,y_train,y_test=train_test_split(X , y , test_size = 0.3,random_state =42)
model.fit(x_train, y_train)
model.score(x_test,y_test)
# Out:
# 0.8072083398290525

# %% [markdown]
# # Gradient Boosting Model

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 330, max_depth = 4, min_samples_split = 2,learning_rate = 0.1, random_state = 42,loss = "ls")

# %%
# fit the model
clf.fit(x_train, y_train)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=4, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=330, presort='auto', random_state=42,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
# print R2 score
acc_clf = clf.score(x_test,y_test)
acc_clf
# Out:
# 0.8789109625402547

# %%
clf_pred = clf.predict(x_test)

# %%
price = clf_pred
print(price[:3])
print(y[:3])
# Out:
# [137547.37684801 313427.91160995 113301.57453024]
# [[208500]
#  [181500]
#  [223500]]

# %% [markdown]
# # Lasso Ridge ElasticNet Models

# %%
# linear model 
# fit really well, to predict training set and test set, Biased variance tradeoff (predict training data well, but not the test data)
# regularization: avoid biased predict training data only. (not too much variance, and biased)
# Lasso = L1 algorithms, Ridge = L2 lgorithms, ElasticNet just the balance bwtn the 2
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_squared_error

# %%
# lasso regression
# declare (finding the algorithms)
lasso = Lasso(random_state = 42)
# fit data
lasso_model = lasso.fit(x_train, y_train)
# prediction
y_predlasso = lasso_model.predict(x_test)
RMSE_lasso = mean_squared_error(y_test,y_predlasso)**0.5 #smaller scale, easier to look at (root mean sqaured error)
r2_lasso = r2_score(y_test,y_predlasso)
print("Lasso RMSE: ",RMSE_lasso)
print("Lasso R2: ",r2_lasso)
# need to do training as well, if r2 and RMSE similar, means it's not over fit
# Out:
# Lasso RMSE:  36681.75823278377
# Lasso R2:  0.8071749344240284

# %%
ridge = Ridge(random_state = 42)
# fit data
ridge_model = ridge.fit(x_train, y_train)
# prediction
y_predridge = ridge_model.predict(x_test)
RMSE_ridge = mean_squared_error(y_test,y_predridge)**0.5 #smaller scale, easier to look at (root mean sqaured error)
r2_ridge = r2_score(y_test,y_predridge)
print("Ridge RMSE: ",RMSE_ridge)
print("Ridge R2: ",r2_ridge)
# Out:
# Ridge RMSE:  36710.33200496032
# Ridge R2:  0.8068744098197658

# %%
elas = ElasticNet(random_state = 42)
# fit data
elas_model = elas.fit(x_train, y_train)
# prediction
y_predelas = elas_model.predict(x_test)
RMSE_elas = mean_squared_error(y_test,y_predelas)**0.5 #smaller scale, easier to look at (root mean sqaured error)
r2_elas = r2_score(y_test,y_predelas)
print("ElasticNet RMSE: ",RMSE_elas)
print("ElasticNet R2: ",r2_elas)
# Out:
# ElasticNet RMSE:  39151.67644338254
# ElasticNet R2:  0.7803334519654002

# %% [markdown]
# # Decision Tree & Random Forest

# %% [markdown]
# ### Since these 2 models are for classification, but we are talking about regression question

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
svc = SVC()
svc.fit(x_train,y_train)
acc_svc = svc.score(x_test,y_test)
acc_svc
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.01598173515981735

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train,y_train)
y_pred = decision_tree.predict(x_test)
acc_decision_tree = decision_tree.score(x_test,y_test)
acc_decision_tree
# Out:
# 0.0

# %%
random_forest = RandomForestClassifier(n_estimators = 100)
random_forest.fit(x_train,y_train)
y_pred = random_forest.predict(x_test)
acc_random_forest = random_forest.score(x_train,y_train)
acc_random_forest
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# 0.987279843444227

# %%
random_forest.score(x_test,y_test)
# Out:
# 0.0

# %% [markdown]
# # Save Model

# %% [markdown]
# ### Since Gradient Boosting Regressor has the highest R2 score, we will use this clf model to make prediction

# %%
# Use Pickle to save the clf model
import pickle
clf_pickle = open("new_clf_model.pkl","wb")
pickle.dump(clf, clf_pickle)

# %%
clf_pickle.close()

# %% [markdown]
# # Load Model

# %%
# loading the saved clf model pickle
clf_model = open("clf_model.pkl","rb")
clf = pickle.load(clf_model)

# %%
overallquality = []
garagecars = []
area = []
fullbaths = []
yearbuilt = []
bedrooms = []
buildingtype = ""
centralair = ""
housestyle = ""

# %%
overallquality.append(input("Overallquality: "))
garagecars.append(input("Garage Cars: "))
area.append(input("Squarefeet: "))
fullbaths.append(input("Fullbaths: "))
yearbuilt.append(input("Year Built: "))
bedrooms.append(input("Bedrooms: "))
buildingtype = input("Building Type: ")
centralair = input("Central Air: ")
housestyle = input("House Style: ")
# Out:
# Overallquality: 10
# Garage Cars: 2
# Squarefeet: 2750
# Fullbaths: 3
# Year Built: 1998
# Bedrooms: 4
# Building Type: BldgType_1Fam
# Central Air: CentralAir_Y
# House Style: HouseStyle_2Story

# %%
pred_df = pd.DataFrame()

pred_df["Overall Quality"] = overallquality
pred_df["Squarefeet"] = area
pred_df["Bedrooms"] = bedrooms
pred_df["Full Baths"] = fullbaths
pred_df["Garage Cars"] = garagecars
pred_df["Year Built"] = yearbuilt


# To add 0, 70 times, to zipcodelist:
dummylist = []
dummylist = 15 * [0]

dummy_df = pd.DataFrame([dummylist])

pred_df[["BldgType_1Fam",'BldgType_2fmCon', 'BldgType_Duplex', 'BldgType_Twnhs',
       'BldgType_TwnhsE', 'CentralAir_N', 'CentralAir_Y', 'HouseStyle_1.5Fin',
       'HouseStyle_1.5Unf', 'HouseStyle_1Story', 'HouseStyle_2.5Fin',
       'HouseStyle_2.5Unf', 'HouseStyle_2Story', 'HouseStyle_SFoyer',
       'HouseStyle_SLvl']] = dummy_df

pred_df.loc[0, buildingtype] = 1
pred_df.loc[0, centralair] = 1
pred_df.loc[0, housestyle] = 1

# %%
prediction = clf.predict(pred_df)
prediction
# Out:
# array([518565.95497123])
